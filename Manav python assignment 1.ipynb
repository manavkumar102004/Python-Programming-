# %%
#ARTHEMITC OPERATORS QUESTION1 
num1=int(input("Enter first number"))
num2=int(input("Enter second number"))
#ADDITION
print("Addition ",num1+num2)
#SUBTRACTION 
print("Subtraction",num1-num2)
#MULTIPLICATION
print("Multiplication",num1*num2)
#DIVISION
print("Division",num1/num2)
#FLOOR DIVISION
print("Floor Division",num1//num2)
#MODULUS
print("Modulus",num1%num2)
#EXPONENTIATION
print("Exponentiation",num1**num2)
# Out:
# Enter first number 13
# Enter second number 12
# Addition  25
# Subtraction 1
# Multiplication 156
# Division 1.0833333333333333
# Floor Division 1
# Modulus 1
# Exponentiation 23298085122481

# %%
#QUESTION 2 INTERCHANGE
#To interchange list items using a temporary variable 
numbers=[10,20,30,40,50,60,70,80,90]
temp=numbers[0]
numbers[0]=numbers[-1]
numbers[-1]=temp 
print("List after swapping with temporary variabl numbers")
print(numbers)
# Out:
# List after swapping with temporary variabl numbers
# [90, 20, 30, 40, 50, 60, 70, 80, 10]

# %%
#QUESTION 3 DICTONARIES 
fashion_dict={"brand":"Ritu Kumar","type":"Ethnic","special":"Anarkalis"}
print(fashion_dict)
# Out:
# {'brand': 'Ritu Kumar', 'type': 'Ethnic', 'special': 'Anarkalis'}

# %%
#Accessing Dictionary Elements 
print(fashion_dict['special'])
# Out:
# Anarkalis

# %%
print(len(fashion_dict))
# Out:
# 3

# %%
print(type(fashion_dict))
# Out:
# <class 'dict'>

# %%
#FOR ACCESSING ITMES IN A DICTIONARY 
z=fashion_dict.get("type")
print(z)
# Out:
# Ethnic

# %%
#KEYS METHOD 
fashion_dict.keys()
# Out:
# dict_keys(['brand', 'type', 'special'])

# %%
fashion_dict.values()
# Out:
# dict_values(['Ritu Kumar', 'Ethnic', 'Anarkalis'])

# %%
# Addition of elements
fashion_dict={"brand":"Ritu Kumar","type":"Ethnic","special":"Anarkalis"}
fashion_dict["Store"]="Mall Of India"
print(fashion_dict)
# Out:
# {'brand': 'Ritu Kumar', 'type': 'Ethnic', 'special': 'Anarkalis', 'Store': 'Mall Of India'}

# %%
m13={"brand":"Ralph Lauren","type":"party","Style":"Modern","launched":"1967","years":[1,2,3,4]}
print(m13)
# Out:
# {'brand': 'Ralph Lauren', 'type': 'party', 'Style': 'Modern', 'launched': '1967', 'years': [1, 2, 3, 4]}

# %%
mm={'name': 'Chanel',
 'year': 1910,
 'founder':'Coco Chanel',
 'Speciality':'Chanel No. 5',
 'place': 'France'}
print(mm)
# Out:
# {'name': 'Chanel', 'year': 1910, 'founder': 'Coco Chanel', 'Speciality': 'Chanel No. 5', 'place': 'France'}

# %%
mm.update({'years':'115'})

# %%
mm.popitem()
# Out:
# ('years', '115')

# %%
print(mm)
# Out:
# {'name': 'Chanel', 'year': 1910, 'founder': 'Coco Chanel', 'Speciality': 'Chanel No. 5', 'place': 'France'}

# %%
mm={'name': 'Chanel', 'year': 1910, 'founder': 'Coco Chanel', 'Speciality': 'Chanel No. 5', 'place': 'France'}
mn=mm.copy()
print(mn)
# Out:
# {'name': 'Chanel', 'year': 1910, 'founder': 'Coco Chanel', 'Speciality': 'Chanel No. 5', 'place': 'France'}

# %%
#Nested Dictionaries 
Brands = {
  "Brand1" : {
    "name" : "Levis",
    "year" : 1853
  },
  "Brand2" : {
    "name" : "Only",
    "year" : 1995
  },
  "Brand3" : {
    "name" : "Vero Moda",
    "year" : 1987
  }
}
print(Brands)
# Out:
# {'Brand1': {'name': 'Levis', 'year': 1853}, 'Brand2': {'name': 'Only', 'year': 1995}, 'Brand3': {'name': 'Vero Moda', 'year': 1987}}

# %%
print(Brands["Brand3"]["year"])
# Out:
# 1987
