# %%
import numpy as np
import pandas as pd
df = pd.read_csv(r"C:\Users\manav\Downloads\The Titanic dataset.csv")
df
# Out:
#          1       2         3                                       4       5  \
# 0       sn  pclass  survived                                     NaN  gender
# 1        1       3         0                             Mr. Anthony    male
# 2        1       3         0                             Mr. Anthony    male
# 3        2       3         0                   Master. Eugene Joseph    male
# 4        3       2         0             Abbott, Mr. Rossmore Edward     NaN
# ...    ...     ...       ...                                     ...     ...
# 1297  1296       2         0  Yrois, Miss. Henriette ("Mrs Harbeck")  female
# 1298  1297       3         0                    Zabour, Miss. Hileni  female
# 1299  1298       3         0               Zakarian, Mr. Mapriededer    male
# 1300  1299       3         0                     Zakarian, Mr. Ortin    male
# 1301  1300       3         0                      Zimmerman, Mr. Leo    male
#
# ...

# %%
df.head()
# Out:
#     1       2         3                            4       5    6       7  \
# 0  sn  pclass  survived                          NaN  gender  age  family
# 1   1       3         0                  Mr. Anthony    male   42       0
# 2   1       3         0                  Mr. Anthony    male   42       0
# 3   2       3         0        Master. Eugene Joseph    male    ?       2
# 4   3       2         0  Abbott, Mr. Rossmore Edward     NaN  NaN       2
#
#        8         9         10
# 0   fare  embarked       date
# 1   7.55       NaN  01-Jan-90
# 2   7.55       NaN  01-Jan-90
# 3  20.25         S  02-Jan-90
# 4     **         S  03-Jan-90

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1302 entries, 0 to 1301
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1       1302 non-null   object
#  1   2       1302 non-null   object
#  2   3       1302 non-null   object
#  3   4       1301 non-null   object
#  4   5       1301 non-null   object
#  5   6       1045 non-null   object
#  6   7       1300 non-null   object
#  7   8       1300 non-null   object
#  8   9       1296 non-null   object
#  9   10      1302 non-null   object
# dtypes: object(10)
# memory usage: 101.8+ KB

# %%
df.describe()
# Out:
#            1     2     3                     4     5     6     7     8     9  \
# count   1302  1302  1302                  1301  1301  1045  1300  1300  1296
# unique  1301     4     3                  1297     3    98    10   283     4
# top        1     3     0  Connolly, Miss. Kate  male    24     0    13     S
# freq       2   700   801                     2   835    47   781    59   905
#
#                10
# count        1302
# unique       1301
# top     01-Jan-90
# freq            2

# %%
df.shape
# Out:
# (1302, 10)

# %%
df.sort_values('10')
# Out:
#          1       2         3                                               4  \
# 92      91       3         0                           Barbara, Miss. Saiide
# 457    456       1         1    Goldenberg, Mrs. Samuel L (Edwiga Grabowska)
# 823    822       3         1                             Moor, Master. Meier
# 1188  1187       3         0                                Thomas, Mr. John
# 214    213       2         0                   Carter, Rev. Ernest Courtenay
# ...    ...     ...       ...                                             ...
# 1248  1247       2         0                      Watson, Mr. Ennis Hastings
# 305    304       1         0                          Davidson, Mr. Thornton
# 670    669       3         0  Klasen, Mrs. (Hulda Kristina Eugenia Lofqvist)
# 1036  1035       3         1                             Roth, Miss. Sarah A
# 0       sn  pclass  survived                                             NaN
#
# ...

# %%
#rename(), which lets change column names.
df.rename(columns={'Duration':"Time Spent"})
# Out:
#          1       2         3                                       4       5  \
# 0       sn  pclass  survived                                     NaN  gender
# 1        1       3         0                             Mr. Anthony    male
# 2        1       3         0                             Mr. Anthony    male
# 3        2       3         0                   Master. Eugene Joseph    male
# 4        3       2         0             Abbott, Mr. Rossmore Edward     NaN
# ...    ...     ...       ...                                     ...     ...
# 1297  1296       2         0  Yrois, Miss. Henriette ("Mrs Harbeck")  female
# 1298  1297       3         0                    Zabour, Miss. Hileni  female
# 1299  1298       3         0               Zakarian, Mr. Mapriededer    male
# 1300  1299       3         0                     Zakarian, Mr. Ortin    male
# 1301  1300       3         0                      Zimmerman, Mr. Leo    male
#
# ...
